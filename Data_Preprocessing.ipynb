# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/content/drive/MyDrive/Final writing/ce889_dataCollection.csv")
data.columns=["X_target","Y_target","Y_velocity","X_Velocity"]

# %%
data.dtypes
# Out:
# X_target      float64
# Y_target      float64
# Y_velocity    float64
# X_Velocity    float64
# dtype: object

# %%
data.drop_duplicates(subset=["X_target","Y_target"],inplace=True)

# %%
data.isna().sum()
# Out:
# X_target      0
# Y_target      0
# Y_velocity    0
# X_Velocity    0
# dtype: int64

# %%
data.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data = (data-data.min())/(data.max()-data.min())

# %%
data.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
X=data.iloc[:,0:2]
y=data.iloc[:,2:]

# %%
from sklearn.model_selection import train_test_split

X_train,X_val_test,y_train,y_val_test = train_test_split(X,y,test_size=0.3,shuffle=True)

X_test,X_valid,y_test,y_valid = train_test_split(X_val_test,y_val_test,test_size=0.5,shuffle=True)
